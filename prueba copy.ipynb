# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %% [markdown]
# ### Función auxiliar para crear las diferentes conexiones al necesitar navegar por la página.
# ### Reibe como parametro la url hacía donde va la conexión y se concatena a la URL base.

# %%
def abrir_conexion(url):
    url_base="https://www.ubereats.com" ##base
    headers = {'Accept': 'text/html'} ##Encabezado para que acepte la conexión
    url_final=url_base+url ##concatenar direcciones
    pagina=requests.get(url_final,headers=headers) ##Hacer el request a la pag
    if pagina.status_code ==200: ##Control para la conexión
        print("Conexión establecida")
        contenido=BeautifulSoup(pagina.content,"html.parser") ##Bajar html
        return contenido
    else:
        print("Conexión fallido")
        return False

# %% [markdown]
# ### Llamado, apertura y consecución del contenido de la página:
#
# ### * Importante, si se desea acceder a la información de otros paises, basta con cambiar '/co/location', por 'xx/location', donde xx representa el dominio de cualquier país. Ejemplo: 'pe/location', para obtener información de Perú.

# %% [markdown]
# ### Extracción de las diferentes ciudades que tiene UberEats registradas en Colombia, además de la extracción de las urls para navegar allí :
#
# ### - A partir de aquí, se trabaja todo con Colombia, dados los parametros de la celda anterior.
#
# ### - Se extraen todas las ciudades y las respectivas URL hacía donde dirigen. Esto con el fin de que sea escalable, por si el día de mañana se agregan otras ciudades no presentes en el momento.

# %%
divTag=[]
while(len(divTag)==0):
    url = '/co/location' ##Url de Colombia. SOLO INTERESA COLOMBIA.
    contenido=abrir_conexion(url) ##abrir pagina 
    divTag = contenido.find_all("div", {"class": "db dc dd de df dg dh"}) ##Etiqueta donde están almacenados las ciudades del país
ciudades=divTag[0].find_all("span", {"class": "bj bk c3 au"}) ##Obtener las ciudades del país
url_ciudades=divTag[0].find_all("a") ##Obtener las urls que dirigen
# Out:
# Conexión establecida

# %%
ciudades=[ciudad.text for ciudad in ciudades] ## Almacenar la lista de ciudades que tiene registradas UberEats en Colombia
url_ciudades=[url["href"] for url in url_ciudades] ##Almacenar Urls para cada ciudad

# %%
print(ciudades)
print(url_ciudades)
# Out:
# ['Antofagasta', 'Arica', 'Concepción', 'Iquique', 'La Serena', 'Puerto Montt', 'Rancagua', 'Santiago', 'Talca', 'Temuco', 'Valparaíso']
# ['/cl/location/antofagasta', '/cl/location/arica', '/cl/location/concepcion', '/cl/location/iquique', '/cl/location/la-serena', '/cl/location/puerto-montt', '/cl/location/rancagua', '/cl/location/santiago', '/cl/location/talca', '/cl/location/temuco', '/cl/location/valparaiso']

# %%
ciudad_categoria={} ##Guardar las ciudades y las categorias de cada ciudad
ciudad_categoria_url={}

# %% [markdown]
# ### Tratando de navegar hacía las Urls de las diferentes ciudades Colombianas, almacenar las diferentes categorias que posee. Fue necesario usar el ciclo while, ya que cuando se hacían multiples request seguidos, muchas veces retornaba vacios. Con el while se asegura que repita la petición hasta que obtenga un resultado.

# %%
for url in range(0,len(url_ciudades)): ##Iterar sobre las ciudades
    categorias_etiqueta=[] ##auxiliar control
    while len(categorias_etiqueta)==0: ##Control para respuestas vacias por recurrencias
        print(url_ciudades[url])
        contenido_ciudad=abrir_conexion(url_ciudades[url]) ##abrir conexión
        while(contenido_ciudad==False):
                    contenido_ciudad=abrir_conexion(url_ciudades[url]) ##abrir conexión


        categorias_etiqueta=contenido_ciudad.find_all("a", {"class": "ey d8 ez"}) ##Obtener las categorias
        categorias_etiqueta2=contenido_ciudad.find_all("a", {"class": "eq d8 er"}) ##Obtener categorias (alternas)
        categorias_etiqueta+=categorias_etiqueta2 #Unirlas
        

    categorias_ciudad=[etiqueta.text for etiqueta in categorias_etiqueta] ##Nombres de categoria por ciudad
    url_categorias=[etiqueta["href"] for etiqueta in categorias_etiqueta] ## Obtener Url de las caterogias por ciudad
    ciudad_categoria[ciudades[url]]=categorias_ciudad ## Guardar ciudad y respectivas categorías.
    ciudad_categoria_url[ciudades[url]]=url_categorias ## Guardar ciudad y respectivas categorías.
# Out:
# /cl/location/antofagasta
# Conexión establecida
# /cl/location/arica
# Conexión establecida
# /cl/location/concepcion
# Conexión establecida
# /cl/location/iquique
# Conexión establecida
# /cl/location/la-serena
# Conexión establecida
# /cl/location/puerto-montt
# Conexión establecida
# /cl/location/rancagua
# Conexión establecida
# /cl/location/santiago
# Conexión establecida
# /cl/location/talca
# Conexión establecida
# /cl/location/temuco
# Conexión establecida
# /cl/location/valparaiso
# Conexión establecida

# %%
#ciudad_categoria

# %% [markdown]
# ### Abrir las conexiones con cada categoria por ciudad y extraer los restaurantes. PARTE CRÍTICA:

# %%
ciudad_categoria_definitiva={}
control_url=[]

# %%
for i in ciudad_categoria_url:
    
    for url in ciudad_categoria_url[i]:
        
        sitio_etiqueta=[]
        while len(sitio_etiqueta)==0:
            contenido_categoria=abrir_conexion(url) ##abrir conexión
            sitio_etiqueta=contenido_categoria.find_all("h3",{"class":"ek bk bl au el al aj em dk"}) 
                             ##Obtener las categorias
        url_restaurante=[]
        for restaurante in sitio_etiqueta:
            url_restaurante.append(restaurante.find_all("a")[0]["href"])

        ciudad_categoria_definitiva[str(i)+"-"+str(url)]=url_restaurante ##Almacenando las lista de restaurantes por ciudad-categoría
# Out:
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión establecida
# Conexión fallido
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-3a1d275e275f> in <module>
#       6         while len(sitio_etiqueta)==0:
#       7             contenido_categoria=abrir_conexion(url) ##abrir conexión
# ----> 8             sitio_etiqueta=contenido_categoria.find_all("h3",{"class":"ek bk bl au el al aj em dk"})
#       9                              ##Obtener las categorias
#      10         url_restaurante=[]
#
# AttributeError: 'bool' object has no attribute 'find_all'

# %%
listarestaurantes=[]

# %% [markdown]
# ### Se accede a cada uno de los diferentes restaurantes, para extraer los atributos requeridos. Posterior a esto se guardan todos como diccionarios, para finalmente llevarlos a un dataFrame.
#
# ### El principal problema que se tuvo acá, fue el hecho de que muchos restaurantes varían en su estrcutura HTML, según el estado en el que se encuentren en el momento. Si está abierto, si está cerrado, si es exclusivo de uberEats. Estos factores alteran la estructura y es necesario programar una extraccíón más dinámica.

# %%
cont=0
for ciudad_categoriaaux in ciudad_categoria_definitiva:
    for restaurante in ciudad_categoria_definitiva[ciudad_categoriaaux]:
        nombre=[]
        categoria_especifica=[]
        calificacion=[]
        reviews=[]
        direccion=[]
        
        cont+=1
        print("Conteo: ", cont)
        

        ##ABIERTO Y CERRADO: ###WHILE VALIDA RESPUESTA
        if restaurante in control_url:
            print("LO TENGO")
            pass 
        else:
            control_url.append(restaurante)
            contenido_restaura=abrir_conexion(restaurante) ## Abrir conexión restaurante
            while(contenido_restaura==False):
                contenido_restaura=abrir_conexion(restaurante) ## Abrir conexión restaurante

            contenido_restaura_aux=contenido_restaura.find("div",{"class":"au at dc dd de df af aq dg"}) #Obtener el nombre, tipo 1
            if contenido_restaura_aux==None:
                print("NO SOY TIPO 1")
                contenido_restaura_aux=contenido_restaura.find("div",{"class":"au at d8 d9 da db af aq dc"})
                if contenido_restaura_aux==None:
                    print("NO SOY TIPO 2")
                    print("NADA POR ACAAAAAAAAAAAA: ", restaurante)
            nombre=contenido_restaura_aux.find_all("h1",{"class":"de df dg as"}) #Obtener el nombre, tipo 1
            if len(nombre)==0:
                nombre=contenido_restaura_aux.find_all("h1",{"class":"di dj dk as"}) ##Nombre, alternativo
                if len(nombre)==0:  ##Peor de los casos, no está el nombre
                    nombre=contenido_restaura_aux.find_all("h1",{"class":"d4 d5 d6 au"}) ##Nombre, alternativo
                    if len(nombre)==0:
                        nombre=""

            categoria_especifica=contenido_restaura_aux.find_all("div",{"class":"c6 cv ba as dh"})  ##Categoria tipo 1
            if len(categoria_especifica)==0:
                categoria_especifica=contenido_restaura_aux.find_all("div",{"class":"c6 cv ba as dl"}) ## Categoria, alternativa 
                if len(categoria_especifica)==0:
                    categoria_especifica=contenido_restaura_aux.find_all("div",{"class":"ct cu ck au ft"})
                    if len(categoria_especifica)==0:

                        categoria_especifica="" ##Peor de los casos, no hay categoría

            calificacion=contenido_restaura_aux.find_all(lambda x: x.name == 'div' and x.get('class') == ['c4']) ##Calificación

            if len(calificacion)==0: 
                calificacion=contenido_restaura_aux.find_all(lambda x: x.name == 'div' and x.get('class') == ['au'])
                if len(calificacion)==0:
                    calificacion=contenido_restaura_aux.find_all(lambda x: x.name == 'div' and x.get('class') == ['as'])
                    if len(calificacion)==0:
                        calificacion=contenido_restaura_aux.find_all(lambda x: x.name == 'div' and x.get('class') == ['an'])
                        if(len(calificacion))==0:
                            calificacion=""##Peor de los casos, calificación vacía






            reviews=contenido_restaura_aux.find_all(lambda x: x.name == 'div' and x.get('class') == ['dj']) ##Revies tipo 1

            if len(reviews)==0:
                reviews=contenido_restaura_aux.find_all(lambda x: x.name == 'div' and x.get('class') == ['dn']) ##Reviews alternat  ivo
                if len(reviews)==0:
                    reviews=contenido_restaura_aux.find_all(lambda x: x.name == 'div' and x.get('class') == ['du']) ##Reviews alternat  ivo
                    if len(reviews)==0:

                        reviews="" ##Peor de los casos, reviews está vacío 

            direccion=contenido_restaura_aux.find_all("p",{"class":"c6 cv ba as dm"}) ##Dirección tiene 4 tipos de variaciones, tipo 1  
            if len(direccion)==0:
                direccion=contenido_restaura_aux.find_all("p",{"class":"c6 cv ba as dq"}) ##tipo 2
                if len(direccion)==0:
                    direccion=contenido_restaura_aux.find_all("p",{"class":"c6 cv ba as dl"}) ## tipo 3
                    if len(direccion)==0:
                        direccion=contenido_restaura_aux.find_all("p",{"class":"c6 cv ba as dp"}) ##tipo 4
                        if len(direccion)==0:
                            direccion=contenido_restaura_aux.find_all("p",{"class":"ct cu ck au h8"}) ##tipo 5
                            if len(direccion)==0:

                                direccion=""  ##Peor de los casos, está vacía
            if (nombre != ""):

                nombre=nombre[0].text
                #print(nombre)
            if (categoria_especifica != ""):
                categoria_especifica=categoria_especifica[0].text
                #print(categoria_especifica)
            if (calificacion != ""):
                try:
                    #print(calificacion)
                    calificacion=calificacion[0].text

                except:
                    print("Calificación:",calificacion)
                    calificacion=""
            #print(calificacion)
            if (reviews != ""):
                reviews=reviews[0].text
                #print(reviews)
            if (direccion != ""):
                direccion=direccion[0].text
                #print(direccion)
            print("-------------------------||||||||||||||||||||||||||||||-------------------------")
    #print(nombre[0].text)
    #print(categoria_especifica[0].text)
    #print(calificacion[0].text)
    #print(reviews[0].text)
    #print(direccion[0].text)
        #print(nombre)
        #print(categoria_especifica)
        #print(calificacion)
        #print(reviews)
        #print(direccion)
        #print(nombre[0].text)
        #print(categoria_especifica[0].text)
        #print(calificacion[0].text)
        #print(reviews[0].text)
        #print(direccion[0].text)

            restaux={"Nombre":nombre,"Categoria_Especifica":categoria_especifica,"Calificacion":calificacion,"Reviews":reviews,"Direccion":direccion, "Url":"https://www.ubereats.com"+restaurante}
        listarestaurantes.append(restaux)
        print(restaux)


        ############CUIDADO QUE YA HAY INDICIOS DE PORQUÉ SE VA SIEMPRE POR LA CONDICIÓN. POR ESA CLASE DE MIERDA. OTRA CLASE CON NOMBRE SIMILAR, LLENA DE MIERDA.
# Out:
# s para alérgicos', 'Calificacion': '4.5', 'Reviews': '(10)', 'Direccion': 'Brasil 1161, La Serena, Coquimbo, Chile, \xa0•\xa0Más información', 'Url': 'https://www.ubereats.com/cl/la-serena/food-delivery/que-guaramos/mVqe5JFmTvyRQmEeG9_oJA'}
# Conteo:  1192
# Conexión establecida
# NO SOY TIPO 1
# -------------------------||||||||||||||||||||||||||||||-------------------------
# {'Nombre': 'Beirut - Av. del Mar', 'Categoria_Especifica': '$ • Árabe', 'Calificacion': '4.6', 'Reviews': '(123)', 'Direccion': 'Av Del Mar 2492, La Serena, Región de Coquimbo\xa0•\xa0Más información', 'Url': 'https://www.ubereats.com/cl/la-serena/food-delivery/beirut-av-del-mar/_JmS-2nxStifigAf7CMCJA'}
# Conteo:  1193
# Conexión establecida
# NO SOY TIPO 1
# -------------------------||||||||||||||||||||||||||||||-------------------------
# {'Nombre': 'Spacio Hub', 'Categoria_Especifica': '$ • Medio Oriente', 'Calificacion': '4.4', 'Reviews': '(86)', 'Direccion': 'Balmaceda 3435, La Serena, Región de Coquimbo 1780000\xa0•\xa0Más información', 'Url': 'https://www.ubereats.com/cl/la-serena/food-delivery/spacio-hub/F3rFMRg0SBWWuTXu-E34og'}
# Conteo:  1194
# Conexión fallido
# Conexión establecida
# -------------------------||||||||||||||||||||||||||||||-------------------------
# {'Nombre': 'Al Nayaj', 'Categoria_Especifica': '$$ • Medio Oriente', 'Calificacion': '', 'Reviews': '', 'Direccion': 'Av Del Mar & Francisco De Aguirre, La Serena, Región de Coquimbo 1710198\xa0•\xa0Más información', 'Url': 'https://www.ubereats.com/cl/la-serena/food-delivery/al-nayaj/U3mEqX_KQSCCahhodw0iOg'}
# Conteo:  1195
# Conexión establecida
# NO SOY TIPO 1
# -------------------------||||||||||||||||||||||||||||||-------------------------
# {'Nombre': 'Sushi ToGo', 'Categoria_Especifica': '$$ • Sushi', 'Calificacion': '4.6', 'Reviews': '(500+)', 'Direccion': 'Guillermo Gallardo 488, Puerto Montt, Los Lagos\xa0•\xa0Más información', 'Url': 'https://www.ubereats.com/cl/puerto-montt/food-delivery/sushi-togo/xYDTOgQVQXiNB1VTLZV1gQ'}
# Conteo:  1196
# Conexión establecida
# NO SOY TIPO 1
# -------------------------||||||||||||||||||||||||||||||-------------------------
# {'Nombre': 'Sushi Bistro', 'Categoria_Especifica': '$$ • Sushi', 'Calificacion': '4.6', 'Reviews': '(304)', 'Direccion': 'Maratón 1020, Puerto Montt, Los Lagos, Chile, \xa0•\xa0Más información', 'Url': 'https://www.ubereats.com/cl/puerto-montt/food-delivery/sushi-bistro/nD7LXIzLQj-eHA5H7HhOOA'}
# Conteo:  1197
# Conexión establecida
# NO SOY TIPO 1
# -------------------------||||||||||||||||||||||||||||||-------------------------
# {'Nombre': "Gaby's Sushi", 'Categoria_Especifica': '$$ • Sushi', 'Calificacion': '4.4', 'Reviews': '(191)', 'Direccion': 'Crucero 1925, Puerto Montt, Los Lagos, Chile, \xa0•\xa0Más información', 'Url': 'https://www.ubereats.com/cl/puerto-montt/food-delivery/gabys-sushi/-3b4xaJbRW2mk77oKIKByQ'}
# Conteo:  1198
# Conexión establecida
# NO SOY TIPO 1
# -------------------------||||||||||||||||||||||||||||||-------------------------
# {'Nombre': 'Breko Sushi Bar - Valle Volcanes', 'Categoria_Especifica': '$$ • Sushi', 'Calificacion': '4.6', 'Reviews': '(116)', 'Direccion': 'Cerro Tronador 4981, Valle Volcanes, Puerto Montt, Los Lagos  Chile, Los Lagos 5480000\xa0•\xa0Más información', 'Url': 'https://www.ubereats.com/cl/puerto-montt/food-delivery/breko-sushi-bar-valle-volcanes/YWvfPsEOQESYjk8oRiNXjg'}
# Conteo:  1199
# Conexión fallido
# Conexión establecida
# NO SOY TIPO 1
# -------------------------||||||||||||||||||||||||||||||-------------------------
# {'Nombre': 'Sushi Factory', 'Categoria_Especifica': '$$ • Sushi', 'Calificacion': '4.4', 'Reviews': '(116)', 'Direccion': 'Guillermo Gallardo 488, Puerto Montt, Los Lagos\xa0•\xa0Más información', 'Url': 'https://www.ubereats.com/cl/puerto-montt/food-delivery/sushi-factory/D8-rmT4HRxqZ7J1glSx39g'}
# Conteo:  1200
# Conexión establecida
# NO SOY TIPO 1
# -------------------------||||||||||||||||||||||||||||||-------------------------
# {'Nombre': 'Breko Sushi Bar - Angelmó', 'Categoria_Especifica': '$$ • Sushi', 'Calificacion': '4.5', 'Reviews': '(70)', 'Direccion': 'Pacheco Altamirano 2539, Puerto Montt, Región de los Lagos\xa0•\xa0Más información', 'Url': 'https://www.ubereats.com/cl/puerto-montt/food-delivery/breko-sushi-bar-angelmo/g24d77_oTqm2iWPXTV9AVQ'}
# Conteo:  1201
# Conexión establecida
# NO SOY TIPO 1
# -------------------------||||||||||||||||||||||||||||||-------------------------
# {'Nombre': 'La Cocina Delivery', 'Categoria_Especifica': '$$ • Sushi', 'Calificacion': '4.6', 'Reviews': '(43)', 'Direccion': 'Maullín 644, Puerto Montt, Los Lagos, Chile, \xa0•\xa0Más información', 'Url': 'https://www.ubereats.com/cl/puerto-montt/food-delivery/la-cocina-delivery/z8kaZGboTqGC_atE0dgOzQ'}
# Conteo:  1202
# Conexión fallido
# Conexión establecida
# NO SOY TIPO 1
# -------------------------||||||||||||||||||||||||||||||-------------------------
# {'Nombre': 'Pukem Sushi', 'Categoria_Especifica': '$$ • Sushi', 'Calificacion': '3.9', 'Reviews': '(14)', 'Direccion': 'Ejército 175, Puerto Montt, Los Lagos, Chile, \xa0•\xa0Más información', 'Url': 'https://www.ubereats.com/cl/puerto-montt/food-delivery/pukem-sushi/JWR8Bz2JRWWDqWnMGHZYXA'}
# Conteo:  1203
# Conexión establecida
# NO SOY TIPO 1
# -------------------------||||||||||||||||||||||||||||||-------------------------
# {'Nombre': 'Oh Sama Sushi', 'Categoria_Especifica': '$$ • Sushi', 'Calificacion': '4.7', 'Reviews': '(100)', 'Direccion': 'Avenida 4ta Terraza 5036, Puerto  Montt,  5480000\xa0•\xa0Más información', 'Url': 'https://www.ubereats.com/cl/puerto-montt/food-delivery/oh-sama-sushi/Dl-H2BIDQkOL4JBDEOK47w'}
# Conteo:  1204
# Conexión fallido
# Conexión fallido
# Conexión establecida
# NO SOY TIPO 1
# -------------------------||||||||||||||||||||||||||||||-------------------------
# {'Nombre': 'Sushi Kanji', 'Categoria_Especifica': '$$ • Sushi', 'Calificacion': '4.4', 'Reviews': '(42)', 'Direccion': 'Guiillermo Gallardo 548, Local 4, Puerto Montt, Región de los Lagos 5480000\xa0•\xa0Más información', 'Url': 'https://www.ubereats.com/cl/puerto-montt/food-delivery/sushi-kanji/XvbLZAJMTsyRpq_3wAi1UQ'}
# Conteo:  1205
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión establecida
# NO SOY TIPO 1
# -------------------------||||||||||||||||||||||||||||||-------------------------
# {'Nombre': 'Musuko Sushi', 'Categoria_Especifica': '$$ • Sushi', 'Calificacion': '4.6', 'Reviews': '(39)', 'Direccion': 'Volcán Puntiagudo 1806, Puerto Montt, Los Lagos, Chile, \xa0•\xa0Más información', 'Url': 'https://www.ubereats.com/cl/puerto-montt/food-delivery/musuko-sushi/jh3VizWhRp2wkpL9zTZB3Q'}
# Conteo:  1206
# Conexión fallido
# Conexión establecida
# NO SOY TIPO 1
# -------------------------||||||||||||||||||||||||||||||-------------------------
# {'Nombre': 'Tako Sushi', 'Categoria_Especifica': '$$ • Sushi', 'Calificacion': '4.2', 'Reviews': '(70)', 'Direccion': 'Guillermo Gallardo 488, Puerto Montt, Los Lagos\xa0•\xa0Más información', 'Url': 'https://www.ubereats.com/cl/puerto-montt/food-delivery/tako-sushi/YxdozQsCRduYThYN2YpnSw'}
# Conteo:  1207
# Conexión establecida
# NO SOY TIPO 1
# -------------------------||||||||||||||||||||||||||||||-------------------------
# {'Nombre': 'Hikari Sushi', 'Categoria_Especifica': '$$ • Sushi', 'Calificacion': '3.4', 'Reviews': '(25)', 'Direccion': 'Cerro Tronador 4958 Valle Volcanes, Puerto Montt, Region De Los Lagos  Chile, Region de los Lagos 5480000\xa0•\xa0Más información', 'Url': 'https://www.ubereats.com/cl/puerto-montt/food-delivery/hikari-sushi/-f1urV5ETZWX3q7SW84KqQ'}
# Conteo:  1208
# Conexión establecida
# NO SOY TIPO 1
# -------------------------||||||||||||||||||||||||||||||-------------------------
# {'Nombre': 'Fusión y Sabor', 'Categoria_Especifica': '$$ • Sushi', 'Calificacion': '', 'Reviews': '', 'Direccion': 'Los Notros 122 B, Puerto Montt, Region de Los Lagos 5480000\xa0•\xa0Más información', 'Url': 'https://www.ubereats.com/cl/puerto-montt/food-delivery/fusion-y-sabor/SWd3fSjVSEixwFaCc9_WRg'}
# Conteo:  1209
# Conexión establecida
# NO SOY TIPO 1
# -------------------------||||||||||||||||||||||||||||||-------------------------
# {'Nombre': 'Kazoku', 'Categoria_Especifica': '$$ • Sushi', 'Calificacion': '', 'Reviews': '', 'Direccion': 'Avenida San Martín 167, Puerto Montt, Región de los Lagos 5480000\xa0•\xa0Más información', 'Url': 'https://www.ubereats.com/cl/puerto-montt/food-delivery/kazoku/eimUUJtKTm-OI_nkZs3XTA'}
# Conteo:  1210
# Conexión establecida
# NO SOY TIPO 1
# -------------------------||||||||||||||||||||||||||||||-------------------------
# {'Nombre': 'Terraza Bistro', 'Categoria_Especifica': '$$ • Sushi', 'Calificacion': '', 'Reviews': '', 'Direccion': 'Janequeo 1000, Puerto Montt, Los Lagos\xa0•\xa0Más información', 'Url': 'https://www.ubereats.com/cl/puerto-montt/food-delivery/terraza-bistro/6GdvSU1ORI2Kc_kSNvVbww'}
# Conteo:  1211
# Conexión establecida
# -------------------------||||||||||||||||||||||||||||||-------------------------
# {'Nombre': 'Breko Sushi Bar - Antihual', 'Categoria_Especifica': '$$ • Sushi', 'Calificacion': '4', 'Reviews': '(44)', 'Direccion': 'Av. Ramon Munita 1625 Local 3, Puerto Montt, Los Lagos 5480000\xa0•\xa0Más información', 'Url': 'https://www.ubereats.com/cl/puerto-montt/food-delivery/breko-sushi-bar-antihual/BSQROwC4Qt2uS-6iKdLXUw'}
# Conteo:  1212
# Conexión establecida
# NO SOY TIPO 1
# -------------------------||||||||||||||||||||||||||||||-------------------------
# {'Nombre': 'Romaji Sushi', 'Categoria_Especifica': '$$ • Sushi', 'Calificacion': '3.9', 'Reviews': '(15)', 'Direccion': 'Guillermo Gallardo 548, Local 4, Puerto Montt, Región de los Lagos 5480000\xa0•\xa0Más información', 'Url': 'https://www.ubereats.com/cl/puerto-montt/food-delivery/romaji-sushi/846Ze1NvRqy6P2_8FG66Zw'}
# Conteo:  1213
# Conexión establecida
# NO SOY TIPO 1
# -------------------------||||||||||||||||||||||||||||||-------------------------
# {'Nombre': 'Kana Sushi', 'Categoria_Especifica': '$$ • Sushi', 'Calificacion': '4.1', 'Reviews': '(11)', 'Direccion': 'Guillermo Gallardo 548, Local 4, Puerto Montt, Región de los Lagos 5480000\xa0•\xa0Más información', 'Url': 'https://www.ubereats.com/cl/puerto-montt/food-delivery/kana-sushi/IdtQWMkFRhKxj0o4MufKBA'}
# Conteo:  1214
# Conexión establecida
# -------------------------||||||||||||||||||||||||||||||-------------------------
# {'Nombre': 'Breko Sushi Bar - Centro', 'Categoria_Especifica': '$$ • Sushi', 'Calificacion': '', 'Reviews': '', 'Direccion': 'Benavente 260, Puerto Montt, Los Lagos, Chile, \xa0•\xa0Más información', 'Url': 'https://www.ubereats.com/cl/puerto-montt/food-delivery/breko-sushi-bar-centro/Ys-sLmH4TMuduEYzfOJLxA'}
# Conteo:  1215
# Conexión establecida
# -------------------------||||||||||||||||||||||||||||||-------------------------
# {'Nombre': 'El Kultrum', 'Categoria_Especifica': '$$ • Sushi', 'Calificacion': '', 'Reviews': '', 'Direccion': 'Ejército 33, Puerto Montt,  5480000\xa0•\xa0Más información', 'Url': 'https://www.ubereats.com/cl/puerto-montt/food-delivery/el-kultrum/TyrpJ68CRs-mkojs5zTSKA'}
# Conteo:  1216
# Conexión establecida
# -------------------------||||||||||||||||||||||||||||||-------------------------
# {'Nombre': 'Sushi Kai', 'Categoria_Especifica': '$$ • Sushi', 'Calificacion': '', 'Reviews': '', 'Direccion': 'Guillermo Gallardo 488, Puerto Montt, Los Lagos, Chile, \xa0•\xa0Más información', 'Url': 'https://www.ubereats.com/cl/puerto-montt/food-delivery/sushi-kai/bLhW29W8T7K0shKIMhq4_w'}
# Conteo:  1217
# Conexión establecida
# NO SOY TIPO 1
# -------------------------||||||||||||||||||||||||||||||-------------------------
# {'Nombre': "Papa John's Pizza - Ramón Munita", 'Categoria_Especifica': '$$ • Pizza', 'Calificacion': '4.7', 'Reviews': '(339)', 'Direccion': '1625 Monseñor Ramon Munita, Puerto Montt, Puerto Montt 5480000\xa0•\xa0Más información', 'Url': 'https://www.ubereats.com/cl/puerto-montt/food-delivery/papa-johns-pizza-ramon-munita/o8byNbg4RyG7boYvohrHhw'}
# Conteo:  1218
# Conexión establecida
# NO SOY TIPO 1
# -------------------------||||||||||||||||||||||||||||||-------------------------
# {'Nombre': "Papa John's Pizza - Lider Ibáñez", 'Categoria_Especifica': '$$ • Pizza', 'Calificacion': '4.6', 'Reviews': '(104)', 'Direccion': 'Parque Industrial 400, Puerto Montt, Los Lagos, Chile, \xa0•\xa0Más información', 'Url': 'https://www.ubereats.com/cl/puerto-montt/food-delivery/papa-johns-pizza-lider-ibanez/1u2xjTPsSFKTTZXqHlJepw'}
# Conteo:  1219
# Conexión establecida
# NO SOY TIPO 1
# -------------------------||||||||||||||||||||||||||||||-------------------------
# {'Nombre': "Domino's Pizza - Puerto Montt", 'Categoria_Especifica': '$$ • Pizza', 'Calificacion': '4.6', 'Reviews': '(207)', 'Direccion': 'Avda Ejercito 508, Puerto Montt, Puerto Montt 5480000\xa0•\xa0Más información', 'Url': 'https://www.ubereats.com/cl/puerto-montt/food-delivery/dominos-pizza-puerto-montt/wvtIpEoEQB2jtPuXI_F4rQ'}
# Conteo:  1220
# Conexión establecida
# NO SOY TIPO 1
# -------------------------||||||||||||||||||||||||||||||-------------------------
# {'Nombre': "Domino's Pizza - Puerto Montt 2", 'Categoria_Especifica': '$$ • Pizza', 'Calificacion': '4.6', 'Reviews': '(107)', 'Direccion': 'Avda Pdte Ibañez 1433 Local 100, Puerto Montt, Puerto Montt 5480000\xa0•\xa0Más información', 'Url': 'https://www.ubereats.com/cl/puerto-montt/food-delivery/dominos-pizza-puerto-montt-2/5Fe8H8fjSRyvphiNRZR95g'}
# Conteo:  1221
# Conexión establecida
# NO SOY TIPO 1
# -------------------------||||||||||||||||||||||||||||||-------------------------
# {'Nombre': 'La Burguesa', 'Categoria_Especifica': '$$ • Hamburguesas', 'Calificacion': '4.2', 'Reviews': '(98)', 'Direccion': 'Federico Ii Oelckers 541, Llanquihue, Región de Los Lagos 5480000\xa0•\xa0Más información', 'Url': 'https://www.ubereats.com/cl/puerto-montt/food-delivery/la-burguesa/dhrDFOJbQ92VpsFfU9SzhA'}
# Conteo:  1222
# Conexión establecida
# NO SOY TIPO 1
# -------------------------||||||||||||||||||||||||||||||-------------------------
# {'Nombre': 'Bonzai Sushi', 'Categoria_Especifica': '$$ • Pizza', 'Calificacion': '4.5', 'Reviews': '(84)', 'Direccion': 'Janequeo, Puerto Montt, Los Lagos\xa0•\xa0Más información', 'Url': 'https://www.ubereats.com/cl/puerto-montt/food-delivery/bonzai-sushi/o6jeThgATLCx_cu49-jffQ'}
# Conteo:  1223
# Conexión establecida
# NO SOY TIPO 1
# -------------------------||||||||||||||||||||||||||||||-------------------------
# {'Nombre': '🛒 Pronto Copec - Puerto Montt', 'Categoria_Especifica': '$ • Conveniencia', 'Calificacion': '4.5', 'Reviews': '(95)', 'Direccion': 'Calle Panamericana Nte. 200, Puerto Montt, Región de los Lagos\xa0•\xa0Más información', 'Url': 'https://www.ubereats.com/cl/puerto-montt/food-delivery/pronto-copec-puerto-montt/61KHEaHtRNCbLzWkUCOJPQ'}
# Conteo:  1224
# Conexión fallido
# Conexión establecida
# NO SOY TIPO 1
# -------------------------||||||||||||||||||||||||||||||-------------------------
# {'Nombre': 'Sherlock', 'Categoria_Especifica': '$$ • Chilena', 'Calificacion': '4.6', 'Reviews': '(45)', 'Direccion': 'Antonio Varas 452, Puerto Montt, Los Lagos\xa0•\xa0Más información', 'Url': 'https://www.ubereats.com/cl/puerto-montt/food-delivery/sherlock/GckchYhCTlGeWLnW_fPSlw'}
# Conteo:  1225
# Conexión establecida
# NO SOY TIPO 1
# -------------------------||||||||||||||||||||||||||||||-------------------------
# {'Nombre': "Di' Nocetti Valle Volcanes", 'Categoria_Especifica': '$$ • Pizza', 'Calificacion': '4.8', 'Reviews': '(120)', 'Direccion': 'Pasaje Loa 4972, Puerto Montt,  5480000 Chile, \xa0•\xa0Más información', 'Url': 'https://www.ubereats.com/cl/puerto-montt/food-delivery/di-nocetti-valle-volcanes/1gQW44yLQxObCsc5EB0dwA'}
# Conteo:  1226
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# Conexión fallido
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-23-18fae0659820> in <module>
#      20             contenido_restaura=abrir_conexion(restaurante) ## Abrir conexión restaurante
#      21             while(contenido_restaura==False):
# ---> 22                 contenido_restaura=abrir_conexion(restaurante) ## Abrir conexión restaurante
#      23
#      24             contenido_restaura_aux=contenido_restaura.find("div",{"class":"au at dc dd de df af aq dg"}) #Obtener el nombre, tipo 1
#
# <ipython-input-13-9f8086b5d6d5> in abrir_conexion(url)
#       3     headers = {'Accept': 'text/html'} ##Encabezado para que acepte la conexión
#       4     url_final=url_base+url ##concatenar direcciones
# ----> 5     pagina=requests.get(url_final,headers=headers) ##Hacer el request a la pag
#       6     if pagina.status_code ==200: ##Control para la conexión
#       7         print("Conexión establecida")
#
# ~\Anaconda3\envs\case_1.1_var2\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# ~\Anaconda3\envs\case_1.1_var2\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# ~\Anaconda3\envs\case_1.1_var2\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     528         }
#     529         send_kwargs.update(settings)
# --> 530         resp = self.send(prep, **send_kwargs)
#     531
#     532         return resp
#
# ~\Anaconda3\envs\case_1.1_var2\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     641
#     642         # Send the request
# --> 643         r = adapter.send(request, **kwargs)
#     644
#     645         # Total elapsed time of the request (approximately)
#
# ~\Anaconda3\envs\case_1.1_var2\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     437         try:
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#     441                     url=url,
#
# ~\Anaconda3\envs\case_1.1_var2\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     663
#     664             # Make the request on the httplib connection object.
# --> 665             httplib_response = self._make_request(
#     666                 conn,
#     667                 method,
#
# ~\Anaconda3\envs\case_1.1_var2\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     419                     # Python 3 (including for exceptions like SystemExit).
#     420                     # Otherwise it looks like a bug in the code.
# --> 421                     six.raise_from(e, None)
#     422         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     423             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# ~\Anaconda3\envs\case_1.1_var2\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# ~\Anaconda3\envs\case_1.1_var2\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     414                 # Python 3
#     415                 try:
# --> 416                     httplib_response = conn.getresponse()
#     417                 except BaseException as e:
#     418                     # Remove the TypeError from the exception chain in
#
# ~\Anaconda3\envs\case_1.1_var2\lib\http\client.py in getresponse(self)
#    1330         try:
#    1331             try:
# -> 1332                 response.begin()
#    1333             except ConnectionError:
#    1334                 self.close()
#
# ~\Anaconda3\envs\case_1.1_var2\lib\http\client.py in begin(self)
#     301         # read until we get a non-100 response
#     302         while True:
# --> 303             version, status, reason = self._read_status()
#     304             if status != CONTINUE:
#     305                 break
#
# ~\Anaconda3\envs\case_1.1_var2\lib\http\client.py in _read_status(self)
#     262
#     263     def _read_status(self):
# --> 264         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     265         if len(line) > _MAXLINE:
#     266             raise LineTooLong("status line")
#
# ~\Anaconda3\envs\case_1.1_var2\lib\socket.py in readinto(self, b)
#     667         while True:
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#     671                 self._timeout_occurred = True
#
# ~\Anaconda3\envs\case_1.1_var2\lib\site-packages\urllib3\contrib\pyopenssl.py in recv_into(self, *args, **kwargs)
#     311     def recv_into(self, *args, **kwargs):
#     312         try:
# --> 313             return self.connection.recv_into(*args, **kwargs)
#     314         except OpenSSL.SSL.SysCallError as e:
#     315             if self.suppress_ragged_eofs and e.args == (-1, "Unexpected EOF"):
#
# ~\Anaconda3\envs\case_1.1_var2\lib\site-packages\OpenSSL\SSL.py in recv_into(self, buffer, nbytes, flags)
#    1837             result = _lib.SSL_peek(self._ssl, buf, nbytes)
#    1838         else:
# -> 1839             result = _lib.SSL_read(self._ssl, buf, nbytes)
#    1840         self._raise_ssl_error(self._ssl, result)
#    1841
#
# KeyboardInterrupt:

# %%
restaurantes=pd.DataFrame(listarestaurantes)

# %%
restaurantes[restaurantes.Calificacion!=""].shape
# Out:
# (27, 6)

# %%
restaurantes.to_csv('restaurantes_chile09062020pm.csv', encoding='utf-8')

# %%
import json
json = json.dumps(ciudad_categoria_definitiva)
f = open("definitivo_ciudad_categoria_chile.json","w")
f.write(json)
f.close()

# %%
contenido_restaura=abrir_conexion('/cl/antofagasta/food-delivery/la-ciudad-nueva/G-geeH24TbaDx5BNOxntTQ') ## Abrir conexión restaurante
contenido_restaura_aux=contenido_restaura.find("div",{"class":"au at dc dd de df af aq dg"}) #Obtener el nombre, tipo 1
if contenido_restaura_aux==None:
    contenido_restaura_aux=contenido_restaura.find("div",{"class":"au at d8 d9 da db af aq dc"})




nombre=contenido_restaura.find_all("h1",{"class":"de df dg as"}) #Obtener el nombre, tipo 1
if len(nombre)==0:
    nombre=contenido_restaura.find_all("h1",{"class":"di dj dk as"}) ##Nombre, alternativo
    if len(nombre)==0:
          ##Peor de los casos, no está el nombre
        nombre=contenido_restaura.find_all("h1",{"class":"d4 d5 d6 au"}) ##Nombre, alternativo
        if len(nombre)==0:
            nombre=""

categoria_especifica=contenido_restaura.find_all("div",{"class":"c6 cv ba as dh"})  ##Categoria tipo 1
if len(categoria_especifica)==0:
    categoria_especifica=contenido_restaura.find_all("div",{"class":"c6 cv ba as dl"}) ## Categoria, alternativa 
    if len(categoria_especifica)==0:
        categoria_especifica=contenido_restaura.find_all("div",{"class":"ct cu ck au ft"})
        if len(categoria_especifica)==0:
            categoria_especifica="" ##Peor de los casos, no hay categoría

calificacion=contenido_restaura.find_all(lambda x: x.name == 'div' and x.get('class') == ['c4']) ##Calificación
#soup.find_all(lambda tag: tag.name == 'li' and tag.get('class') == ['z'])
if len(calificacion)==0:
     calificacion=contenido_restaura.find_all(lambda x: x.name == 'div' and x.get('class') == ['au'])
     if len(calificacion)==0:
         calificacion=contenido_restaura.find_all(lambda x: x.name == 'div' and x.get('class') == ['as'])
         if len(calificacion)==0:

             calificacion=contenido_restaura.find_all(lambda x: x.name == 'div' and x.get('class') == ['an'])
             if(len(calificacion))==0:
                 calificacion=""##Peor de los casos, calificación vacía

#css_soup.find_all("p", class_="body strikeout"


            

reviews=contenido_restaura.find_all(lambda x: x.name == 'div' and x.get('class') == ['dj']) ##Revies tipo 1
if len(reviews)==0:
    reviews=contenido_restaura.find_all(lambda x: x.name == 'div' and x.get('class') == ['dn']) ##Reviews alternativo
    if len(reviews)==0:
        reviews=contenido_restaura.find_all(lambda x: x.name == 'div' and x.get('class') == ['du']) ##Reviews alternativo
        if len(reviews)==0:
            reviews="" ##Peor de los casos, reviews está vacío 

direccion=contenido_restaura.find_all("p",{"class":"c6 cv ba as dm"}) ##Dirección tiene 4 tipos de variaciones, tipo 1
if len(direccion)==0:
    direccion=contenido_restaura.find_all("p",{"class":"c6 cv ba as dq"}) ##tipo 2
    if len(direccion)==0:
        direccion=contenido_restaura.find_all("p",{"class":"c6 cv ba as dl"}) ## tipo 3
        if len(direccion)==0:
            direccion=contenido_restaura.find_all("p",{"class":"c6 cv ba as dp"}) ##tipo 4
            if len(direccion)==0:
                direccion=contenido_restaura.find_all("p",{"class":"ct cu ck au h8"}) ##tipo 5
                if len(direccion)==0:
                    direccion=""  ##Peor de los casos, está vacía
if (nombre != ""):
    nombre=nombre[0].text
            #print(nombre)
if (categoria_especifica != ""):
    categoria_especifica=categoria_especifica[0].text
            #print(categoria_especifica)
if (calificacion != ""):
    try:

        print(calificacion)
        calificacion=calificacion[0].text
                
    except:

        print("Calificación:",calificacion)
        calificacion=""
            #print(calificacion)
if (reviews != ""):
    reviews=reviews[0].text
            #print(reviews)
if (direccion != ""):
    direccion=direccion[0].text
            #print(direccion)
print("-------------------------||||||||||||||||||||||||||||||-------------------------")
    #print(nombre[0].text)
    #print(categoria_especifica[0].text)
    #print(calificacion[0].text)
    #print(reviews[0].text)
    #print(direccion[0].text)
        #print(nombre)
        #print(categoria_especifica)
        #print(calificacion)
        #print(reviews)
        #print(direccion)
        #print(nombre[0].text)
        #print(categoria_especifica[0].text)
        #print(calificacion[0].text)
        #print(reviews[0].text)
        #print(direccion[0].text)
restaux={"Nombre":nombre,"Categoria_Especifica":categoria_especifica,"Calificacion":calificacion,"Reviews":reviews,"Direccion":direccion} #"Url":"https://www.ubereats.com"+restaurante}
        #listarestaurantes.append(restaux)
print(restaux)
